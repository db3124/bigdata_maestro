# %% [markdown]
# # 강서구 비환경적 요인 다중회귀분석

# %%
import pandas as pd

gs = pd.read_excel('./res/강서구_연도별.xlsx') 
x = gs[['old_man', 'nohu', 'apart', 'dasedae', 'dandok', 'bijugeo', 'yeonlib']]

y = gs[['kwh']]

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

plt.scatter(gs[['old_man']], gs[['kwh']], c='#56B76A', alpha = 0.4)
sns.regplot(x='old_man', y='kwh', data=gs)

plt.title('고령인구 비율과 전력 사용량의 상관성')
plt.xlabel('고령인구 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gs[['nohu']], gs[['kwh']], c='#56B76A' ,alpha = 0.4)
sns.regplot(x='nohu', y='kwh', data=gs)

plt.title('노후주택 비율과 전력 사용량의 상관성')
plt.xlabel('노후주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gs[['apart']], gs[['kwh']], c='#56B76A' ,alpha = 0.4)
sns.regplot(x='apart', y='kwh', data=gs)

plt.title('아파트 비율과 전력 사용량의 상관성')
plt.xlabel('아파트 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gs[['dasedae']], gs[['kwh']], c='#56B76A' ,alpha = 0.4)
sns.regplot(x='dasedae', y='kwh', data=gs)

plt.title('다세대주택 비율과 전력 사용량의 상관성')
plt.xlabel('다세대주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gs[['dandok']], gs[['kwh']], c='#56B76A' ,alpha = 0.4)
sns.regplot(x='dandok', y='kwh', data=gs)

plt.title('단독주택 비율과 전력 사용량의 상관성')
plt.xlabel('단독주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gs[['bijugeo']], gs[['kwh']], c='#56B76A' ,alpha = 0.4)
sns.regplot(x='bijugeo', y='kwh', data=gs)

plt.title('비주거용 건물용 주택 비율과 전력 사용량의 상관성')
plt.xlabel('비주거용 건물용 주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gs[['yeonlib']], gs[['kwh']], c='#56B76A', alpha = 0.4)
sns.regplot(x='yeonlib', y='kwh', data=gs)

plt.title('연립주택 비율과 전력 사용량의 상관성')
plt.xlabel('연립주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %% [markdown]
# # 강남구 비환경적 요인 다중회귀분석

# %%
import pandas as pd

gn = pd.read_excel('./res/강남구_연도별.xlsx') 
x = gn[['old_man', 'nohu', 'apart', 'dasedae', 'dandok', 'bijugeo', 'yeonlib']]

y = gn[['kwh']]

# %%
plt.scatter(gn[['old_man']], gn[['kwh']], c='#063B94', alpha = 0.4)
sns.regplot(x='old_man', y='kwh', data=gn)

plt.title('고령인구 비율과 전력 사용량의 상관성')
plt.xlabel('고령인구 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gn[['nohu']], gn[['kwh']], c='#063B94', alpha = 0.4)
sns.regplot(x='nohu', y='kwh', data=gn)

plt.title('노후주택 비율과 전력 사용량의 상관성')
plt.xlabel('노후주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gn[['apart']], gn[['kwh']], c='#063B94', alpha = 0.4)
sns.regplot(x='apart', y='kwh', data=gn)

plt.title('아파트 비율과 전력 사용량의 상관성')
plt.xlabel('아파트 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gn[['dasedae']], gn[['kwh']], c='#063B94', alpha = 0.4)
sns.regplot(x='dasedae', y='kwh', data=gn)

plt.title('다세대주택 비율과 전력 사용량의 상관성')
plt.xlabel('다세대주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gn[['dandok']], gn[['kwh']], c='#063B94', alpha = 0.4)
sns.regplot(x='dandok', y='kwh', data=gn)

plt.title('단독주택 비율과 전력 사용량의 상관성')
plt.xlabel('단독주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gn[['bijugeo']], gn[['kwh']], c='#063B94', alpha = 0.4)
sns.regplot(x='bijugeo', y='kwh', data=gn)

plt.title('비주거용 건물용 주택 비율과 전력 사용량의 상관성')
plt.xlabel('비주거용 건물용 주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gn[['yeonlib']], gn[['kwh']], c='#063B94', alpha = 0.4)
sns.regplot(x='yeonlib', y='kwh', data=gn)

plt.title('연립주택 비율과 전력 사용량의 상관성')
plt.xlabel('연립주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %% [markdown]
# # 서초구 비환경적 요인 다중회귀분석

# %%
import pandas as pd

sc = pd.read_excel('./res/서초구_연도별.xlsx') 
x = sc[['old_man', 'nohu', 'apart', 'dasedae', 'dandok', 'bijugeo', 'yeonlib']]

y = sc[['kwh']]

# %%
plt.scatter(sc[['old_man']], sc[['kwh']], c='#F04E98', alpha = 0.4)
sns.regplot(x='old_man', y='kwh', data=sc)

plt.title('고령인구 비율과 전력 사용량의 상관성')
plt.xlabel('고령인구 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sc[['nohu']], sc[['kwh']], c='#F04E98', alpha = 0.4)
sns.regplot(x='nohu', y='kwh', data=sc)

plt.title('노후주택 비율과 전력 사용량의 상관성')
plt.xlabel('노후주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sc[['apart']], sc[['kwh']], c='#F04E98', alpha = 0.4)
sns.regplot(x='apart', y='kwh', data=sc)

plt.title('아파트 비율과 전력 사용량의 상관성')
plt.xlabel('아파트 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sc[['dasedae']], sc[['kwh']], c='#F04E98', alpha = 0.4)
sns.regplot(x='dasedae', y='kwh', data=sc)

plt.title('다세대주택 비율과 전력 사용량의 상관성')
plt.xlabel('다세대주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sc[['dandok']], sc[['kwh']], c='#F04E98', alpha = 0.4)
sns.regplot(x='dandok', y='kwh', data=sc)

plt.title('단독주택 비율과 전력 사용량의 상관성')
plt.xlabel('단독주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sc[['bijugeo']], sc[['kwh']], c='#F04E98', alpha = 0.4)
sns.regplot(x='bijugeo', y='kwh', data=sc)

plt.title('비주거용 건물용 주택 비율과 전력 사용량의 상관성')
plt.xlabel('비주거용 건물용 주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sc[['yeonlib']], sc[['kwh']], c='#F04E98', alpha = 0.4)
sns.regplot(x='yeonlib', y='kwh', data=sc)

plt.title('연립용 주택 비율과 전력 사용량의 상관성')
plt.xlabel('연립용 건물용 주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %% [markdown]
# # 송파구 비환경적 요인 다중회귀분석

# %%
import pandas as pd

sp = pd.read_excel('./res/송파구_연도별.xlsx') 
x = sp[['old_man', 'nohu', 'apart', 'dasedae', 'dandok', 'bijugeo', 'yeonlib']]

y = sp[['kwh']]

# %%
plt.scatter(sp[['old_man']], sp[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='old_man', y='kwh', data=sp)

plt.title('고령인구 비율과 전력 사용량의 상관성')
plt.xlabel('고령인구 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sp[['nohu']], sp[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='nohu', y='kwh', data=sp)

plt.title('노후주택 비율과 전력 사용량의 상관성')
plt.xlabel('노후주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sp[['apart']], sp[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='apart', y='kwh', data=sp)

plt.title('아파트 비율과 전력 사용량의 상관성')
plt.xlabel('아파트 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sp[['dasedae']], sp[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='dasedae', y='kwh', data=sp)

plt.title('다세대주택 비율과 전력 사용량의 상관성')
plt.xlabel('다세대주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sp[['dandok']], sp[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='dandok', y='kwh', data=sp)

plt.title('단독주택 비율과 전력 사용량의 상관성')
plt.xlabel('단독주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sp[['bijugeo']], sp[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='bijugeo', y='kwh', data=sp)

plt.title('비주거용 건물용 주택 비율과 전력 사용량의 상관성')
plt.xlabel('비주거용 건물용 주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sp[['yeonlib']], sp[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='yeonlib', y='kwh', data=sp)

plt.title('연립주택 비율과 전력 사용량의 상관성')
plt.xlabel('연립주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %% [markdown]
# # 노원구 비환경적 요인 다중회귀분석

# %%
import pandas as pd

nw = pd.read_excel('./res/노원구_연도별.xlsx') 
x = nw[['old_man', 'nohu', 'apart', 'dasedae', 'dandok', 'bijugeo', 'yeonlib']]

y = nw[['kwh']]

# %%
plt.scatter(nw[['old_man']], nw[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='old_man', y='kwh', data=nw)

plt.title('고령인구 비율과 전력 사용량의 상관성')
plt.xlabel('고령인구 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(nw[['nohu']], nw[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='nohu', y='kwh', data=nw)

plt.title('노후주택 비율과 전력 사용량의 상관성')
plt.xlabel('노후주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(nw[['apart']], nw[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='apart', y='kwh', data=nw)

plt.title('아파트 비율과 전력 사용량의 상관성')
plt.xlabel('아파트 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(nw[['dasedae']], nw[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='dasedae', y='kwh', data=nw)

plt.title('다세대주택 비율과 전력 사용량의 상관성')
plt.xlabel('다세대주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(nw[['dandok']], nw[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='dandok', y='kwh', data=nw)

plt.title('단독주택 비율과 전력 사용량의 상관성')
plt.xlabel('단독주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(nw[['bijugeo']], nw[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='bijugeo', y='kwh', data=nw)

plt.title('비주거용 건물용 비율과 전력 사용량의 상관성')
plt.xlabel('비주거용 건물용 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(nw[['yeonlib']], nw[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='yeonlib', y='kwh', data=nw)

plt.title('연립주택 비율과 전력 사용량의 상관성')
plt.xlabel('연립주택 비율(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %% [markdown]
# # 강서구 환경적 요인 다중회귀분석

# %%
import pandas as pd

gs_eco = pd.read_excel('./res/강서구_연도별.xlsx') 
x = gs_eco[['ondo', 'seupdo']]

y = gs_eco[['kwh']]

# %%
plt.scatter(gs_eco[['ondo']], gs_eco[['kwh']], c='#56B76A', alpha = 0.4)
sns.regplot(x='ondo', y='kwh', data=gs_eco)

plt.title('기온과 전력 사용량의 상관성')
plt.xlabel('기온(ºC)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gs_eco[['seupdo']], gs_eco[['kwh']], c='#56B76A', alpha = 0.4)
sns.regplot(x='seupdo', y='kwh', data=gs_eco)

plt.title('습도와 전력 사용량의 상관성')
plt.xlabel('습도(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %% [markdown]
# # 강남구 환경적 요인 다중회귀분석

# %%
import pandas as pd

gn_eco = pd.read_excel('./res/강남구_연도별.xlsx') 
x = gn_eco[['ondo', 'seupdo']]

y = gn_eco[['kwh']]

# %%
plt.scatter(gn_eco[['ondo']], gn_eco[['kwh']], c='#063B94', alpha = 0.4)
sns.regplot(x='ondo', y='kwh', data=gn_eco)

plt.title('기온과 전력 사용량의 상관성')
plt.xlabel('기온(ºC)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(gn_eco[['seupdo']], gn_eco[['kwh']], c='#063B94', alpha = 0.4)
sns.regplot(x='seupdo', y='kwh', data=gn_eco)

plt.title('습도와 전력 사용량의 상관성')
plt.xlabel('습도(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %% [markdown]
# # 서초구 환경적 요인 다중회귀분석

# %%
import pandas as pd

sc_eco = pd.read_excel('./res/서초구_연도별.xlsx') 
x = sc_eco[['ondo', 'seupdo']]

y = sc_eco[['kwh']]

# %%
plt.scatter(sc_eco[['ondo']], sc_eco[['kwh']], c='#F04E98', alpha = 0.4)
sns.regplot(x='ondo', y='kwh', data=sc_eco)

plt.title('기온과 전력 사용량의 상관성')
plt.xlabel('기온(ºC)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sc_eco[['seupdo']], sc_eco[['kwh']], c='#F04E98', alpha = 0.4)
sns.regplot(x='seupdo', y='kwh', data=sc_eco)

plt.title('습도와 전력 사용량의 상관성')
plt.xlabel('습도(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %% [markdown]
# # 송파구 환경적 요인 다중회귀분석

# %%
import pandas as pd

sp_eco = pd.read_excel('./res/송파구_연도별.xlsx') 
x = sp_eco[['ondo', 'seupdo']]

y = sp_eco[['kwh']]

# %%
plt.scatter(sp_eco[['ondo']], sp_eco[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='ondo', y='kwh', data=sp_eco)

plt.title('기온과 전력 사용량의 상관성')
plt.xlabel('기온(ºC)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(sp_eco[['seupdo']], sp_eco[['kwh']], c='#007DBA', alpha = 0.4)
sns.regplot(x='seupdo', y='kwh', data=sp_eco)

plt.title('습도와 전력 사용량의 상관성')
plt.xlabel('습도(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %% [markdown]
# # 노원구 환경적 요인 다중회귀분석

# %%
import pandas as pd

nw_eco = pd.read_excel('./res/노원구_연도별.xlsx') 
x = nw_eco[['ondo', 'seupdo']]

y = nw_eco[['kwh']]

# %%
plt.scatter(nw_eco[['ondo']], nw_eco[['kwh']], c='#A9D784', alpha = 0.4)
sns.regplot(x='ondo', y='kwh', data=nw_eco)

plt.title('기온과 전력 사용량의 상관성')
plt.xlabel('기온(ºC)')
plt.ylabel('전력 사용량(kWh)')

plt.show()

# %%
plt.scatter(nw_eco[['seupdo']], nw_eco[['kwh']], c='#A9D784', alpha = 0.4)
sns.regplot(x='seupdo', y='kwh', data=nw_eco)

plt.title('습도와 전력 사용량의 상관성')
plt.xlabel('습도(%)')
plt.ylabel('전력 사용량(kWh)')

plt.show()
