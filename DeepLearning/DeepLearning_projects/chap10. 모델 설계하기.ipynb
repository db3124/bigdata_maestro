# %%
from tensorflow.keras.models import Sequential # 클래스
from tensorflow.keras.layers import Dense # 함수

# %%
# 필요한 라이브러리 불러옴
import numpy as np
import tensorflow as tf

# %%
# 실행할 때마가 같은 결과를 출력하기 위해 설정하는 부분
np.random.seed(3)
tf.random.set_seed(3)

# %%
# 준비된 수술 환자 데이터를 불러옴
Data_set = np.loadtxt("./dataset/ThoraricSurgery.csv", delimiter = ',')

# %%
# 환자의 기록과 수술 결과를 X와 Y로 구분하여 저장
X = Data_set[:, 0:17]
Y = Data_set[:, 17]

# %%
# 딥러닝 구조를 결정(모델을 설정하고 실행하는 부분)
model = Sequential()
model.add(Dense(30, input_dim = 17, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
# 딥러닝 실행
model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['accuracy'])
model.fit(X, Y, epochs = 100, batch_size = 10)
# Out:
# Train on 470 samples
# Epoch 1/100
# 470/470 [==============================] - 0s 870us/sample - loss: 0.1495 - accuracy: 0.8404
# Epoch 2/100
# 470/470 [==============================] - 0s 116us/sample - loss: 0.1447 - accuracy: 0.8511
# Epoch 3/100
# 470/470 [==============================] - 0s 80us/sample - loss: 0.1448 - accuracy: 0.8511
# Epoch 4/100
# 470/470 [==============================] - 0s 80us/sample - loss: 0.1453 - accuracy: 0.8489
# Epoch 5/100
# 470/470 [==============================] - 0s 73us/sample - loss: 0.1438 - accuracy: 0.8511
# Epoch 6/100
# 470/470 [==============================] - 0s 73us/sample - loss: 0.1418 - accuracy: 0.8511
# Epoch 7/100
# 470/470 [==============================] - 0s 86us/sample - loss: 0.1425 - accuracy: 0.8511
# Epoch 8/100
# 470/470 [==============================] - 0s 85us/sample - loss: 0.1427 - accuracy: 0.8468
# Epoch 9/100
# 470/470 [==============================] - 0s 78us/sample - loss: 0.1446 - accuracy: 0.8489
# ...

# %%
from tensorflow.keras.models import Sequential # 클래스
from tensorflow.keras.layers import Dense # 함수

# 필요한 라이브러리 불러옴
import numpy as np
import tensorflow as tf

# 실행할 때마가 같은 결과를 출력하기 위해 설정하는 부분
np.random.seed(3)
tf.random.set_seed(3)

# 준비된 수술 환자 데이터를 불러옴
Data_set = np.loadtxt("./dataset/ThoraricSurgery.csv", delimiter = ',')

# 환자의 기록과 수술 결과를 X와 Y로 구분하여 저장
X = Data_set[:, 0:17]
Y = Data_set[:, 17]

# 딥러닝 구조를 결정(모델을 설정하고 실행하는 부분)
model = Sequential()
model.add(Dense(30, input_dim = 17, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# 딥러닝 실행
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.fit(X, Y, epochs = 100, batch_size = 10)
# Out:
# Train on 470 samples
# Epoch 1/100
# 470/470 [==============================] - 0s 463us/sample - loss: 0.6902 - accuracy: 0.8106
# Epoch 2/100
# 470/470 [==============================] - 0s 101us/sample - loss: 0.4568 - accuracy: 0.8511
# Epoch 3/100
# 470/470 [==============================] - 0s 72us/sample - loss: 0.4714 - accuracy: 0.8447
# Epoch 4/100
# 470/470 [==============================] - 0s 72us/sample - loss: 0.4609 - accuracy: 0.8447
# Epoch 5/100
# 470/470 [==============================] - 0s 71us/sample - loss: 0.4535 - accuracy: 0.8511
# Epoch 6/100
# 470/470 [==============================] - 0s 75us/sample - loss: 0.4576 - accuracy: 0.8532
# Epoch 7/100
# 470/470 [==============================] - 0s 85us/sample - loss: 0.4410 - accuracy: 0.8511
# Epoch 8/100
# 470/470 [==============================] - 0s 128us/sample - loss: 0.4306 - accuracy: 0.8511
# Epoch 9/100
# 470/470 [==============================] - 0s 65us/sample - loss: 0.4469 - accuracy: 0.8511
# ...

# %%
from tensorflow.keras.models import Sequential # 클래스
from tensorflow.keras.layers import Dense # 함수

# 필요한 라이브러리 불러옴
import numpy as np
import tensorflow as tf

# 실행할 때마가 같은 결과를 출력하기 위해 설정하는 부분
np.random.seed(3)
tf.random.set_seed(3)

# 준비된 수술 환자 데이터를 불러옴
Data_set = np.loadtxt("./dataset/ThoraricSurgery.csv", delimiter = ',')

# 환자의 기록과 수술 결과를 X와 Y로 구분하여 저장
X = Data_set[:, 0:17]
Y = Data_set[:, 17]

# 딥러닝 구조를 결정(모델을 설정하고 실행하는 부분)
model = Sequential()
model.add(Dense(30, input_dim = 17, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# 딥러닝 실행 # 확률적 경사 하강법sgd, 아다그라드adagrad, 알엠에스프롭rmsprop(아다그라드의 보폭 민감도 보완)
model.compile(loss = 'binary_crossentropy', optimizer = 'rmsprop', metrics = ['accuracy'])
model.fit(X, Y, epochs = 100, batch_size = 10)
# Out:
# Train on 470 samples
# Epoch 1/100
# 470/470 [==============================] - 0s 552us/sample - loss: 0.6388 - accuracy: 0.7894
# Epoch 2/100
# 470/470 [==============================] - 0s 88us/sample - loss: 0.4826 - accuracy: 0.8277
# Epoch 3/100
# 470/470 [==============================] - 0s 71us/sample - loss: 0.4829 - accuracy: 0.8362
# Epoch 4/100
# 470/470 [==============================] - 0s 89us/sample - loss: 0.4824 - accuracy: 0.8319
# Epoch 5/100
# 470/470 [==============================] - 0s 92us/sample - loss: 0.4537 - accuracy: 0.8426
# Epoch 6/100
# 470/470 [==============================] - 0s 68us/sample - loss: 0.4731 - accuracy: 0.8298
# Epoch 7/100
# 470/470 [==============================] - 0s 93us/sample - loss: 0.4738 - accuracy: 0.8319
# Epoch 8/100
# 470/470 [==============================] - 0s 66us/sample - loss: 0.4888 - accuracy: 0.8170
# Epoch 9/100
# 470/470 [==============================] - 0s 89us/sample - loss: 0.4565 - accuracy: 0.8426
# ...
